# %% [markdown]
# # **Georgia Disasters Optical HYDRAFloods Code**

# %% [markdown]
# **Table of Contents**
#
#
# 1. Overview of HYDRAFloods
# 2. Set-Up
# 3. Data Acquisition
# 5. Optical Imagery Processing and Analysis
# *   Landsat 8 OLI
# *   Landsat 7 ETM+
# *   Combined Landsat 8 & 7
# *   Sentinel 2 MSI

# %% [markdown]
# # **1. Overview**
# HYDRAFloods - Hydrologic Remote Sensing Analysis for Floods
#
# HYDRAFloods is a Google Earth Engine (GEE) with Python API based application developed by NASA SERVIR. The application uses satellite imagery to produce flood water maps which can aid in response to flood related disasters.
#
# This tutorial will walk-through the steps to apply HYDRAFloods to optical imagery to create flood water maps. For this example, we will examine 15 Georgia counties during Hurricanes Irma in September of 2017.
#
# Study Location: Berrien, Camden, Charlton, Chatham, Coffee, Cook, Crisp, Dougherty, Glynn, Liberty, McIntosh, Thomas, Turner, Wilcox, and Worth counties, GA
#
# This tutorial was developed as part of the Georgia Disasters Project for the NASA DEVELOP Program during the Fall 2022 term.

# %% [markdown]
# The complete documentation for HYDRAFloods can be found [here.](https://servir-mekong.github.io/hydra-floods/)

# %% [markdown]
# # **2. Set-Up**

# %%
# Mount the drive, authenticate and save credentials
# Click the link, select the appropriate Google Drive Account, and copy the authorization token. Paste the token into the box below.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# install HYDRAFloods using Python package installer (pip)
# when this step completes, it will show a warning that you will need to restart. Please ignore this warning.
# !pip install hydrafloods geemap rasterio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting hydrafloods
#   Downloading hydrafloods-2021.10.11-py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 3.6 MB/s
# Collecting geemap
#   Downloading geemap-0.17.2-py2.py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 15.1 MB/s
# Collecting rasterio
#   Downloading rasterio-1.2.10-cp37-cp37m-manylinux1_x86_64.whl (19.3 MB)
#      |████████████████████████████████| 19.3 MB 5.6 MB/s
# Collecting gcsfs
#   Downloading gcsfs-2022.11.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: earthengine-api in /usr/local/lib/python3.7/dist-packages (from hydrafloods) (0.1.330)
# Collecting pipetools
#   Downloading pipetools-1.1.0.tar.gz (16 kB)
# Collecting simplecmr
#   Downloading simplecmr-0.0.1-py3-none-any.whl (6.9 kB)
# Collecting fire
#   Downloading fire-0.4.0.tar.gz (87 kB)
#      |████████████████████████████████| 87 kB 6.4 MB/s
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from geemap) (1.21.6)
# Collecting whiteboxgui>=0.6.0
#   Downloading whiteboxgui-2.2.0-py2.py3-none-any.whl (99 kB)
#      |████████████████████████████████| 99 kB 10.5 MB/s
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from geemap) (3.2.2)
# Collecting scooby
#   Downloading scooby-0.7.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from geemap) (7.1.2)
# Collecting geojson
#   Downloading geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Collecting ee-extra>=0.0.10
#   Downloading ee_extra-0.0.14.tar.gz (198 kB)
#      |████████████████████████████████| 198 kB 62.5 MB/s
# Collecting bqplot
#   Downloading bqplot-0.12.36-py2.py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 55.9 MB/s
# Collecting ipyevents
#   Downloading ipyevents-2.0.1-py2.py3-none-any.whl (130 kB)
#      |████████████████████████████████| 130 kB 50.6 MB/s
# Collecting python-box
#   Downloading python_box-6.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 42.3 MB/s
# Requirement already satisfied: folium>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from geemap) (0.12.1.post1)
# Collecting jupyterlab>=3
#   Downloading jupyterlab-3.5.0-py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 43.5 MB/s
# Collecting pycrs
#   Downloading PyCRS-1.0.2.tar.gz (36 kB)
# Collecting sankee>=0.1.0
#   Downloading sankee-0.2.0.tar.gz (29 kB)
# Collecting colour
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Collecting ipytree
#   Downloading ipytree-0.2.2-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 47.8 MB/s
# Collecting xyzservices
#   Downloading xyzservices-2022.9.0-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 4.1 MB/s
# Collecting geocoder
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 9.8 MB/s
# Collecting ipyfilechooser>=0.6.0
#   Downloading ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# Collecting ipyleaflet>=0.17.0
#   Downloading ipyleaflet-0.17.2-py3-none-any.whl (3.7 MB)
#      |████████████████████████████████| 3.7 MB 49.4 MB/s
# Collecting geeadd>=0.5.1
#   Downloading geeadd-0.5.6-py3-none-any.whl (30 kB)
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (from geemap) (4.4.0)
# Collecting pyshp>=2.1.3
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 4.8 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from geemap) (1.3.5)
# Requirement already satisfied: google-api-python-client<2,>=1.12.1 in /usr/local/lib/python3.7/dist-packages (from earthengine-api->hydrafloods) (1.12.11)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.7/dist-packages (from earthengine-api->hydrafloods) (2.5.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from earthengine-api->hydrafloods) (0.17.4)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from earthengine-api->hydrafloods) (0.16.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from earthengine-api->hydrafloods) (0.0.4)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from earthengine-api->hydrafloods) (2.14.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from earthengine-api->hydrafloods) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from earthengine-api->hydrafloods) (2.23.0)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from folium>=0.11.0->geemap) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.7/dist-packages (from folium>=0.11.0->geemap) (2.11.3)
# Collecting logzero>=1.5.0
#   Downloading logzero-1.7.0-py2.py3-none-any.whl (16 kB)
# Collecting beautifulsoup4>=4.9.0
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 67.8 MB/s
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client<2,>=1.12.1->earthengine-api->hydrafloods) (2.8.2)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client<2,>=1.12.1->earthengine-api->hydrafloods) (3.0.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api->hydrafloods) (1.56.4)
# Requirement already satisfied: protobuf<5.0.0dev,>=3.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api->hydrafloods) (3.19.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.4.1->earthengine-api->hydrafloods) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.4.1->earthengine-api->hydrafloods) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.4.1->earthengine-api->hydrafloods) (0.2.8)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.7/dist-packages (from ipyfilechooser>=0.6.0->geemap) (7.7.1)
# Collecting traittypes<3,>=0.2.1
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (7.9.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.1.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.6.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.3.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.3)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.0.4)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.1.12)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.10)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.4.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.6.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (57.4.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.1-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 56.0 MB/s
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2>=2.9->folium>=0.11.0->geemap) (2.0.1)
# Collecting nbclassic
#   Downloading nbclassic-0.4.8-py3-none-any.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 47.4 MB/s
# Requirement already satisfied: tomli in /usr/local/lib/python3.7/dist-packages (from jupyterlab>=3->geemap) (2.0.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from jupyterlab>=3->geemap) (4.11.2)
# Collecting jupyter-server<3,>=1.16.0
#   Downloading jupyter_server-1.23.2-py3-none-any.whl (346 kB)
#      |████████████████████████████████| 346 kB 57.3 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from jupyterlab>=3->geemap) (21.3)
# Collecting tornado>=4.2
#   Downloading tornado-6.2-cp37-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (423 kB)
#      |████████████████████████████████| 423 kB 55.3 MB/s
# Requirement already satisfied: notebook<7 in /usr/local/lib/python3.7/dist-packages (from jupyterlab>=3->geemap) (5.7.16)
# Collecting jupyterlab-server~=2.10
#   Downloading jupyterlab_server-2.16.3-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 103 kB/s
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.7/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab>=3->geemap) (0.13.3)
# Collecting argon2-cffi
#   Downloading argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.7/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab>=3->geemap) (0.15.0)
# Collecting websocket-client
#   Downloading websocket_client-1.4.2-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 4.0 MB/s
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab>=3->geemap) (1.8.0)
# Requirement already satisfied: nbformat>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab>=3->geemap) (5.7.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.7/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab>=3->geemap) (23.2.1)
# Collecting anyio<4,>=3.1.0
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 10.7 MB/s
# Collecting nbconvert>=6.4.4
#   Downloading nbconvert-7.2.5-py3-none-any.whl (273 kB)
#      |████████████████████████████████| 273 kB 71.0 MB/s
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.7/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab>=3->geemap) (2.10)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab>=3->geemap) (4.1.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.8.2)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /usr/local/lib/python3.7/dist-packages (from jupyterlab-server~=2.10->jupyterlab>=3->geemap) (4.13.0)
# Collecting json5
#   Downloading json5-0.9.10-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: babel in /usr/local/lib/python3.7/dist-packages (from jupyterlab-server~=2.10->jupyterlab>=3->geemap) (2.11.0)
# Requirement already satisfied: jsonschema>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from jupyterlab-server~=2.10->jupyterlab>=3->geemap) (4.3.3)
# Collecting jinja2>=2.9
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 45.3 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.3->jupyterlab-server~=2.10->jupyterlab>=3->geemap) (3.10.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3->geemap) (0.19.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3->geemap) (5.10.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3->geemap) (22.1.0)
# Collecting mistune<3,>=2.0.3
#   Downloading mistune-2.0.4-py2.py3-none-any.whl (24 kB)
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.7.0-py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 255 kB/s
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab>=3->geemap) (1.5.0)
# Collecting tinycss2
#   Downloading tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab>=3->geemap) (5.0.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab>=3->geemap) (0.7.1)
# Collecting traitlets>=4.3.1
#   Downloading traitlets-5.5.0-py3-none-any.whl (107 kB)
#      |████████████████████████████████| 107 kB 42.6 MB/s
# Collecting nest-asyncio
#   Downloading nest_asyncio-1.5.6-py3-none-any.whl (5.2 kB)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat>=5.2.0->jupyter-server<3,>=1.16.0->jupyterlab>=3->geemap) (2.16.2)
# Collecting notebook<7
#   Downloading notebook-6.5.2-py3-none-any.whl (439 kB)
#      |████████████████████████████████| 439 kB 60.5 MB/s
# Collecting notebook-shim>=0.1.0
#   Downloading notebook_shim-0.2.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api->hydrafloods) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->earthengine-api->hydrafloods) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->earthengine-api->hydrafloods) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->earthengine-api->hydrafloods) (2022.9.24)
# Requirement already satisfied: plotly>=5.2.2 in /usr/local/lib/python3.7/dist-packages (from sankee>=0.1.0->geemap) (5.5.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly>=5.2.2->sankee>=0.1.0->geemap) (8.1.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.3->jupyter-server<3,>=1.16.0->jupyterlab>=3->geemap) (0.7.0)
# Collecting whitebox
#   Downloading whitebox-2.2.0-py2.py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 10.1 MB/s
# Collecting affine
#   Downloading affine-2.3.1-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from rasterio) (7.1.2)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Collecting click-plugins
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.7/dist-packages (from snuggs>=1.4.1->rasterio) (3.0.9)
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
#      |████████████████████████████████| 86 kB 3.6 MB/s
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab>=3->geemap) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab>=3->geemap) (2.21)
# Requirement already satisfied: pytz>=2015.7 in /usr/local/lib/python3.7/dist-packages (from babel->jupyterlab-server~=2.10->jupyterlab>=3->geemap) (2022.6)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab>=3->geemap) (0.5.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from fire->hydrafloods) (2.1.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.7/dist-packages (from gcsfs->hydrafloods) (3.8.3)
# Collecting fsspec==2022.11.0
#   Downloading fsspec-2022.11.0-py3-none-any.whl (139 kB)
#      |████████████████████████████████| 139 kB 65.8 MB/s
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.7/dist-packages (from gcsfs->hydrafloods) (0.4.6)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->hydrafloods) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->hydrafloods) (6.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->hydrafloods) (0.13.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->hydrafloods) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->hydrafloods) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->hydrafloods) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->hydrafloods) (1.3.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown->geemap) (4.64.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from gdown->geemap) (3.8.0)
# Collecting ratelim
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib->gcsfs->hydrafloods) (1.3.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs->hydrafloods) (3.2.2)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage->earthengine-api->hydrafloods) (2.4.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage->earthengine-api->hydrafloods) (2.3.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.7/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage->earthengine-api->hydrafloods) (1.5.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->geemap) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->geemap) (0.11.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests->earthengine-api->hydrafloods) (1.7.1)
# Collecting requests-cache
#   Downloading requests_cache-0.9.7-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 5.6 MB/s
# Collecting cattrs>=22.2
#   Downloading cattrs-22.2.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.7/dist-packages (from requests-cache->simplecmr->hydrafloods) (1.4.4)
# Collecting url-normalize>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 49.2 MB/s
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.0.4-py3-none-any.whl (14 kB)
# Building wheels for collected packages: ee-extra, sankee, fire, pipetools, pycrs
#   Building wheel for ee-extra (setup.py) ... done
#   Created wheel for ee-extra: filename=ee_extra-0.0.14-py3-none-any.whl size=209115 sha256=9b4c040e0aea2a64ed66b6028e4ef5783ec84370f57ee2dfbd7930cca52ba1d8
#   Stored in directory: /root/.cache/pip/wheels/50/1f/56/c638a525bcb6972c82e422747430d756edea7d57b539229bb3
#   Building wheel for sankee (setup.py) ... done
#   Created wheel for sankee: filename=sankee-0.2.0-py3-none-any.whl size=28744 sha256=c2186db9651c096b7da423745c5858037ed889005239756b662d425e2989d0b0
#   Stored in directory: /root/.cache/pip/wheels/36/b4/ac/84c3f06e5c44d3fe5029713232438862881e6e1f26657d5fd8
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115940 sha256=16c0068f68be0d601877860088258c13e44b286cbbf82c2e187a7456705287fb
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
#   Building wheel for pipetools (setup.py) ... done
#   Created wheel for pipetools: filename=pipetools-1.1.0-py3-none-any.whl size=13622 sha256=52f006fee2ecaac456037b2300579049ad54eb8a016e4540adedbcbb5effe546
#   Stored in directory: /root/.cache/pip/wheels/db/e4/55/098fde0def89ca29d2cf30f27b19e299c835ce2a08fcc592d6
#   Building wheel for pycrs (setup.py) ... done
#   Created wheel for pycrs: filename=PyCRS-1.0.2-py3-none-any.whl size=32705 sha256=6caf75636139c28a1adbece93e553a1f1e65ff30850466b59cca0eb6eeb1c010
#   Stored in directory: /root/.cache/pip/wheels/3e/ce/32/1ec0aba6b9770681a423e82f0274c57d09ad2c20c2864901f9
# Successfully built ee-extra sankee fire pipetools pycrs
# Installing collected packages: traitlets, tornado, soupsieve, nest-asyncio, tinycss2, sniffio, nbclient, mistune, jupyterlab-pygments, jinja2, beautifulsoup4, argon2-cffi-bindings, websocket-client, nbconvert, jedi, argon2-cffi, anyio, jupyter-server, urllib3, notebook-shim, nbclassic, notebook, exceptiongroup, url-normalize, json5, cattrs, xyzservices, whitebox, traittypes, requests-cache, ratelim, logzero, jupyterlab-server, ipytree, ipyfilechooser, fsspec, whiteboxgui, snuggs, simplecmr, scooby, sankee, python-box, pyshp, pycrs, pipetools, jupyterlab, ipyleaflet, ipyevents, geojson, geocoder, geeadd, gcsfs, fire, ffmpeg-python, ee-extra, colour, cligj, click-plugins, bqplot, affine, rasterio, hydrafloods, geemap
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.1.1
#     Uninstalling traitlets-5.1.1:
#       Successfully uninstalled traitlets-5.1.1
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.0.4
#     Uninstalling tornado-6.0.4:
#       Successfully uninstalled tornado-6.0.4
#   Attempting uninstall: mistune
#     Found existing installation: mistune 0.8.4
#     Uninstalling mistune-0.8.4:
#       Successfully uninstalled mistune-0.8.4
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 5.6.1
#     Uninstalling nbconvert-5.6.1:
#       Successfully uninstalled nbconvert-5.6.1
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: notebook
#     Found existing installation: notebook 5.7.16
#     Uninstalling notebook-5.7.16:
#       Successfully uninstalled notebook-5.7.16
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.10.0
#     Uninstalling fsspec-2022.10.0:
#       Successfully uninstalled fsspec-2022.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires notebook~=5.7.16, but you have notebook 6.5.2 which is incompatible.
# google-colab 1.0.0 requires tornado~=6.0.4, but you have tornado 6.2 which is incompatible.
# flask 1.1.4 requires Jinja2<3.0,>=2.10.1, but you have jinja2 3.1.2 which is incompatible.
# Successfully installed affine-2.3.1 anyio-3.6.2 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 beautifulsoup4-4.11.1 bqplot-0.12.36 cattrs-22.2.0 click-plugins-1.1.1 cligj-0.7.2 colour-0.1.5 ee-extra-0.0.14 exceptiongroup-1.0.4 ffmpeg-python-0.2.0 fire-0.4.0 fsspec-2022.11.0 gcsfs-2022.11.0 geeadd-0.5.6 geemap-0.17.2 geocoder-1.38.1 geojson-2.5.0 hydrafloods-2021.10.11 ipyevents-2.0.1 ipyfilechooser-0.6.0 ipyleaflet-0.17.2 ipytree-0.2.2 jedi-0.18.1 jinja2-3.1.2 json5-0.9.10 jupyter-server-1.23.2 jupyterlab-3.5.0 jupyterlab-pygments-0.2.2 jupyterlab-server-2.16.3 logzero-1.7.0 mistune-2.0.4 nbclassic-0.4.8 nbclient-0.7.0 nbconvert-7.2.5 nest-asyncio-1.5.6 notebook-6.5.2 notebook-shim-0.2.2 pipetools-1.1.0 pycrs-1.0.2 pyshp-2.3.1 python-box-6.1.0 rasterio-1.2.10 ratelim-0.1.6 requests-cache-0.9.7 sankee-0.2.0 scooby-0.7.0 simplecmr-0.0.1 sniffio-1.3.0 snuggs-1.4.7 soupsieve-2.3.2.post1 tinycss2-1.2.1 tornado-6.2 traitlets-5.5.0 traittypes-0.2.1 url-normalize-1.4.3 urllib3-1.25.11 websocket-client-1.4.2 whitebox-2.2.0 whiteboxgui-2.2.0 xyzservices-2022.9.0

# %%
# loading imports for the program
import ee          
import datetime
import hydrafloods as hf
import geemap.eefolium as geemap
import geemap.colormaps as cm

# %%
# authenticate GEE Account
# Click the link, select your GEE Account, copy the token, and paste it into the box below.
_ = geemap.Map()
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=whhiS9GJp77HpYuWCrq3hnTludBWxMd6m_lMKTaO4Lw&tc=VaDqgR5XtNGBLY_bxoH5lGrpSEbZCV7GZQ8MnITly4Q&cc=yMKvqVmHSQD1nKO1zyoFWUINHR4G1EvETKyc8lyZ-AQ
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1AfgeXvtD5F9V0zl57IuZuhioOIqq1qerYTzKDfOOoOsMu5y3fTpYpG3C_Ik
#
# Successfully saved authorization token.

# %% [markdown]
# # **3. Data Acquisition**

# %%
# define region of interest, using shapefile with one feature
region = ee.FeatureCollection("projects/ee-tesfayinathan/assets/15counties").geometry()

# %%
# define time period
# for this example, we will use September 10 - 21, 2017 corresponding to Hurricanes Irma
startTime = datetime.datetime(2017, 9, 10);
endTime = datetime.datetime(2017, 9, 21);

# %%
# getting optical imagery from Landsat 8 based on time period & region
ls8 = hf.Landsat8(region, startTime, endTime);

# %%
# checking for number of images we were able to retrieve from Landsat 8
ls8.n_images
# Out:
# 4

# %%
# getting optical imagery from Landsat 7 based on time period & region
ls7 = hf.Landsat7(region, startTime, endTime);

# %%
# checking number of images we were able to retrieve from Landsat 7
ls7.n_images
# Out:
# 2

# %%
ls7.dates
# Out:
# ['2017-09-20 16:09:33.380', '2017-09-20 16:09:57.270']

# %%
# getting optical imagery from Sentinel-2 MSI based on time period & region
s2 = hf.Sentinel2(region, startTime, endTime);

# %%
# checking number of images we were able to retrieve from Sentinel-2 MSI
s2.n_images
# Out:
# 0

# %% [markdown]
# # **5. Optical Imagery Processing and Analysis**

# %% [markdown]
# ## Landsat 8

# %%
#appy mode reducer to image collection
ls8_image = ls8.collection.reduce('mode')

# %%
#rename bands for MNDWI function
ls8bands = ls8_image.select(['blue_mode', 'green_mode', 'red_mode', 'nir_mode', 'swir1_mode', 'swir2_mode']).rename(
    ['blue', 'green', 'red', 'nir', 'swir1', 'swir2'])

# %%
#get mNDWI (modified Normalized Difference Water Index)
ls8_mndwi = hf.mndwi(ls8bands)

# %%
#apply water thresholding algorithm edge otsu, using 300m buffer and 30m scale
landsat8_water = hf.edge_otsu(ls8_mndwi, region = region, edge_buffer = 300, scale = 300, invert = True, thresh_no_data =0.0)

# %%
#retrieve last 5 years of permanent water to compare against current water
#this will allow us to differentiate between flood water and permanent surface water
#we use the JRC dataset to retrieve the 'permanent water'
permanent_water_ls8 = (
    ee.ImageCollection("JRC/GSW1_2/YearlyHistory") # get the JRC historical dataset
    .filterDate("1985-01-01",endTime) # filter for historical data up to date of interest
    .limit(5, "system:time_start", False) # grab the 5 latest images
    .map(lambda x: x.select("waterClass").eq(3)) # extract out the permanent water class
    .sum() # check if a pixel has been classified as permanent water in the past 5 years
    .unmask(0)
    .gt(0)
).updateMask(landsat8_water.gte(0)) # mask for only the water image we just calculated

# %%
#compare our landsat image water detected vs the permanent water map to differentiate flood water 
# from permanent surface water
floods_ls8 = landsat8_water.add(permanent_water_ls8).eq(1).selfMask()

# %% [markdown]
# ### Full Landsat 8 Map

# %%
#map results/ visualize results
Map = geemap.Map(center=(32, -82.8297), zoom=8)

#Add permanent water layer to map, clip map to region of interest
Map.addLayer(permanent_water_ls8.selfMask(),{"min":0, "max":1,"palette": cm.palettes.Blues}, 'Permanent Water map') 

#Add flood water layer to map, clip map to region of interest
Map.addLayer(floods_ls8.selfMask(),{"min":0, "max":1,"palette":cm.palettes.Reds}, 'Flood map')

#Add county layers
Map.addLayer(region)

Map.addLayerControl()
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9dbd08b84c1e5644305746dddb3c2aac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9dbd08b84c1e5644305746dddb3c2aac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9dbd08b84c1e5644305746dddb3c2aac = L.map(
#                 &quot;map_9dbd08b84c1e5644305746dddb3c2aac&quot;,
#                 {
#                     center: [32.0, -82.8297],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: true,
#                     pluginFullscreen: true,
#                     pluginDraw: false,
#                     DrawExport: true,
#                     pluginMinimap: false,
#                     pluginLayercontrol: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8fc94a57c3bd9abee7df07c904df54cc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9dbd08b84c1e5644305746dddb3c2aac);
#
#
#             var tile_layer_6cf968d28c3925ec9568f04c9055c8b7 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9dbd08b84c1e5644305746dddb3c2aac);
#
#
#                 var lat_lng_popup_70075e91bb8d215d2d30335de9bc9ad7 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_70075e91bb8d215d2d30335de9bc9ad7
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_9dbd08b84c1e5644305746dddb3c2aac);
#                     }
#                 map_9dbd08b84c1e5644305746dddb3c2aac.on(&#x27;click&#x27;, latLngPop);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_9dbd08b84c1e5644305746dddb3c2aac);
#
#
#             map_9dbd08b84c1e5644305746dddb3c2aac.fitBounds(
#                 [[32, -82.8297], [32, -82.8297]],
#                 {&quot;maxZoom&quot;: 8}
#             );
#
#
#             var tile_layer_da477c17f316a82c0098ae2a2ee18877 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/4738befcaccf23053555b4bd46df7efd-58cfc633784323afd3c101887579040f/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1.0, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9dbd08b84c1e5644305746dddb3c2aac);
#
#
#             var tile_layer_db3a13730b6e2558869bd5f62e683bb4 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/12eeb677f369622ba22979275e5d54c4-4bca4387adaa991e308c6613b3281108/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1.0, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9dbd08b84c1e5644305746dddb3c2aac);
#
#
#             var tile_layer_fbf6c10ae4631ce8d166279ba960d867 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/6c232c15c6138fbaf07a71dd0ab78e0b-c328860a4f52a2cc9de482cb714abfee/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1.0, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9dbd08b84c1e5644305746dddb3c2aac);
#
#
#             var layer_control_d974a757

# %% [markdown]
# ### Clipped Landsat 8 Map

# %%
#map results/ visualize results
Map = geemap.Map(center=(32, -82.8297), zoom=8)

#Add permanent water layer to map, clip map to region of interest
Map.addLayer(permanent_water_ls8.selfMask().clip(region),{"min":0, "max":1,"palette": cm.palettes.Blues}, 'Permanent Water map') 

#Add flood water layer to map, clip map to region of interest
Map.addLayer(floods_ls8.selfMask().clip(region),{"min":0, "max":1,"palette":cm.palettes.Reds}, 'Flood map')

#Add county polygon layer
Map.addLayer(region)

Map.addLayerControl()
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e671aa8512d9015b028a3739f35be599 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e671aa8512d9015b028a3739f35be599&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e671aa8512d9015b028a3739f35be599 = L.map(
#                 &quot;map_e671aa8512d9015b028a3739f35be599&quot;,
#                 {
#                     center: [32.0, -82.8297],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: true,
#                     pluginFullscreen: true,
#                     pluginDraw: false,
#                     DrawExport: true,
#                     pluginMinimap: false,
#                     pluginLayercontrol: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_42aa82f3207c5cfced71d9088ffa4763 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e671aa8512d9015b028a3739f35be599);
#
#
#             var tile_layer_6cf968d28c3925ec9568f04c9055c8b7 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e671aa8512d9015b028a3739f35be599);
#
#
#                 var lat_lng_popup_f2cf7a5efe54e7921865f4db2908b08f = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_f2cf7a5efe54e7921865f4db2908b08f
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_e671aa8512d9015b028a3739f35be599);
#                     }
#                 map_e671aa8512d9015b028a3739f35be599.on(&#x27;click&#x27;, latLngPop);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_e671aa8512d9015b028a3739f35be599);
#
#
#             map_e671aa8512d9015b028a3739f35be599.fitBounds(
#                 [[32, -82.8297], [32, -82.8297]],
#                 {&quot;maxZoom&quot;: 8}
#             );
#
#
#             var tile_layer_a8298f0b5a5a2322b76c2739e8794d02 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/dae8af866a28a6744be4e58cb331cc69-2e37ce7732d0e39832e4701eb604a00d/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1.0, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e671aa8512d9015b028a3739f35be599);
#
#
#             var tile_layer_ea0df5bdfe02c592ebee8f2b7c67009d = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/d93322843e1e30f8e6a9a49318ffe8b9-fd7ab8ca0f664a7c0a3168799650f4ff/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1.0, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e671aa8512d9015b028a3739f35be599);
#
#
#             var tile_layer_577943d776c27db373870982d5bae10c = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/6c232c15c6138fbaf07a71dd0ab78e0b-e8eb3f92359d067ac4a97581236c8864/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1.0, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e671aa8512d9015b028a3739f35be599);
#
#
#             var layer_control_1a1f2926

# %%
task = ee.batch.Export.image.toDrive(image=floods_ls8,
                                     description='ls8',
                                     scale=30,
                                     region= region,
                                     crs='EPSG:4326',
                                     fileFormat='GeoTIFF')

# %%
task = ee.batch.Export.image.toDrive(image=permanent_water_ls8,
                                     description='permanent_water',
                                     scale=30,
                                     region= region,
                                     crs='EPSG:4326',
                                     fileFormat='GeoTIFF')

# %%
# export image using HYDRAFloods export image function. below is function with its parameters
# if the export times out or is taking too long, try exporting at a larger scale (ex 90m)

# hf.export_image(floods_ls8, region, description = "clipped_landsat_8", scale=30, crs='EPSG:4326', pyramiding=".default:mode", export_type='toDrive')

# export with visualizations attached to it - ask Vanessa 
# arc, export map layout, export as pdf/png/jpg

# %%
# Export to asset example
# hf.export_image(floods_ls8, region, description = "clipped_landsat_8", scale=30,  crs='EPSG:4326', pyramiding={"water":"mode"}, export_type='toAsset', asset_id = "projects/ichittumuri/assets/studyarea")

# %% [markdown]
# ## Landsat 7

# %%
#appy mode reducer to image collection
ls7_image = ls7.collection.reduce('mode')

# %%
#rename bands for MNDWI function
ls7bands = ls7_image.select(['blue_mode', 'green_mode', 'red_mode', 'nir_mode', 'swir1_mode', 'swir2_mode']).rename(
    ['blue', 'green', 'red', 'nir', 'swir1', 'swir2'])

# %%
#get mNDWI (modified Normalized Difference Water Index)
ls7_mndwi = hf.mndwi(ls7bands)

# %%
#apply water thresholding algorithm edge otsu, using 300m buffer and 30m scale
landsat7_water = hf.edge_otsu(ls7_mndwi, region = region, edge_buffer = 300, scale = 300, invert = True, thresh_no_data =0.0)

# %%
#retrieve last 5 years of permanent water to compare against current water
#this will allow us to differentiate between flood water and permanent surface water
#we use the JRC dataset to retrieve the 'permanent water'
permanent_water_ls7 = (
    ee.ImageCollection("JRC/GSW1_2/YearlyHistory") # get the JRC historical dataset
    .filterDate("1985-01-01",endTime) # filter for historical data up to date of interest
    .limit(5, "system:time_start", False) # grab the 5 latest images
    .map(lambda x: x.select("waterClass").eq(3)) # extract out the permanent water class
    .sum() # check if a pixel has been classified as permanent water in the past 5 years
    .unmask(0)
    .gt(0)
).updateMask(landsat7_water.gte(0)) # mask for only the water image we just calculated

# %%
#compare our landsat image water detected vs the permanent water map to differentiate flood water 
# from permanent surface water
floods_ls7 = landsat7_water.add(permanent_water_ls7).eq(1).selfMask()

# %% [markdown]
# ### Full Landsat 7 Map

# %%
#map results/ visualize results
Map = geemap.Map(center=(32, -82.8297), zoom=8)

#Add permanent water layer to map
Map.addLayer(permanent_water_ls7.selfMask(),{"min":0, "max":1,"palette": cm.palettes.Blues}, 'Permanent Water map') 

#Add flood water layer to map
Map.addLayer(floods_ls7.selfMask(),{"min":0, "max":1,"palette":cm.palettes.Reds}, 'Flood map')

#Add county layers
Map.addLayer(region)

Map.addLayerControl()
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8df85f7ef2a76348f37771a7962c96a8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8df85f7ef2a76348f37771a7962c96a8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8df85f7ef2a76348f37771a7962c96a8 = L.map(
#                 &quot;map_8df85f7ef2a76348f37771a7962c96a8&quot;,
#                 {
#                     center: [32.0, -82.8297],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: true,
#                     pluginFullscreen: true,
#                     pluginDraw: false,
#                     DrawExport: true,
#                     pluginMinimap: false,
#                     pluginLayercontrol: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b02d0f2c35785fe117191236d9a2fe5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8df85f7ef2a76348f37771a7962c96a8);
#
#
#             var tile_layer_6cf968d28c3925ec9568f04c9055c8b7 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8df85f7ef2a76348f37771a7962c96a8);
#
#
#                 var lat_lng_popup_1e95e6eabceace5d5e043d276a974c54 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_1e95e6eabceace5d5e043d276a974c54
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_8df85f7ef2a76348f37771a7962c96a8);
#                     }
#                 map_8df85f7ef2a76348f37771a7962c96a8.on(&#x27;click&#x27;, latLngPop);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_8df85f7ef2a76348f37771a7962c96a8);
#
#
#             map_8df85f7ef2a76348f37771a7962c96a8.fitBounds(
#                 [[32, -82.8297], [32, -82.8297]],
#                 {&quot;maxZoom&quot;: 8}
#             );
#
#
#             var tile_layer_99adecb543fdb7d2598b9d50eb341e10 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/a138a477cea473eda81fefcfa9f556ef-12b8597745585ef69cdb03e99dfe7e46/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1.0, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8df85f7ef2a76348f37771a7962c96a8);
#
#
#             var tile_layer_54d72c8cdc7353b258e3efe6a7b2b997 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/585278502e3473dd51e2a12b3abf7cf9-454496898c781b763c7b187114e27d30/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1.0, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8df85f7ef2a76348f37771a7962c96a8);
#
#
#             var tile_layer_2ab23e8a8ca80cc0149c00c768d47e75 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/6c232c15c6138fbaf07a71dd0ab78e0b-86bd2952c25423a953ce6d2448b33d51/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1.0, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8df85f7ef2a76348f37771a7962c96a8);
#
#
#             var layer_control_d751277d

# %% [markdown]
# ### Clipped Landsat 7 Map

# %%
#map results/ visualize results
Map = geemap.Map(center=(32, -82.8297), zoom=8)

#Add permanent water layer to map
Map.addLayer(permanent_water_ls7.selfMask().clip(region),{"min":0, "max":1,"palette": cm.palettes.Blues}, 'Permanent Water map') 

#Add flood water layer to map
Map.addLayer(floods_ls7.selfMask().clip(region),{"min":0, "max":1,"palette":cm.palettes.Reds}, 'Flood map')

#Add county layers
Map.addLayer(region)

Map.addLayerControl()
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_47f06b4f2046e8d2e4becbd20635fe6f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_47f06b4f2046e8d2e4becbd20635fe6f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_47f06b4f2046e8d2e4becbd20635fe6f = L.map(
#                 &quot;map_47f06b4f2046e8d2e4becbd20635fe6f&quot;,
#                 {
#                     center: [32.0, -82.8297],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: true,
#                     pluginFullscreen: true,
#                     pluginDraw: false,
#                     DrawExport: true,
#                     pluginMinimap: false,
#                     pluginLayercontrol: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c842eea00380e7ba3bb482eb77a7e538 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_47f06b4f2046e8d2e4becbd20635fe6f);
#
#
#             var tile_layer_6cf968d28c3925ec9568f04c9055c8b7 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_47f06b4f2046e8d2e4becbd20635fe6f);
#
#
#                 var lat_lng_popup_0bb3a7adaf4e6848bc74a35d7e620af9 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_0bb3a7adaf4e6848bc74a35d7e620af9
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_47f06b4f2046e8d2e4becbd20635fe6f);
#                     }
#                 map_47f06b4f2046e8d2e4becbd20635fe6f.on(&#x27;click&#x27;, latLngPop);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_47f06b4f2046e8d2e4becbd20635fe6f);
#
#
#             map_47f06b4f2046e8d2e4becbd20635fe6f.fitBounds(
#                 [[32, -82.8297], [32, -82.8297]],
#                 {&quot;maxZoom&quot;: 8}
#             );
#
#
#             var tile_layer_c79232a3c56688eed9901d475b0e59bb = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/1c99aa0022d073102c62faf7b21896af-a2cff4737fafa2e5ad3f6047fbad5511/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1.0, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_47f06b4f2046e8d2e4becbd20635fe6f);
#
#
#             var tile_layer_920ba91d1cebfff25d3e191b7266c8f1 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/8ccf6db8749369304807a1e97de2f046-c09be7d54b6a09bbe13689b492524b95/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1.0, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_47f06b4f2046e8d2e4becbd20635fe6f);
#
#
#             var tile_layer_1b7beb89cb0dbe50b8434789564c1601 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/6c232c15c6138fbaf07a71dd0ab78e0b-de1ee2b0df917554dbe2dc71f268b9a2/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1.0, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_47f06b4f2046e8d2e4becbd20635fe6f);
#
#
#             var layer_control_06e47f55

# %%
# export image using HYDRAFloods export image function. below is function with its parameters
# if the export times out or is taking too long, try exporting at a larger scale (ex 90m)
# can change export_type = 'toAsset'

# hf.export_image(floods_ls7, region, description = "clipped_landsat_7", scale=30, crs='EPSG:4326', pyramiding=".default:mode", export_type='toDrive')

# %%
task = ee.batch.Export.image.toDrive(image=floods_ls7,
                                     description='ls7',
                                     scale=30,
                                     region= region,
                                     crs='EPSG:4326',
                                     fileFormat='GeoTIFF')

# %% [markdown]
# ## Combined Clipped Landsat 8 & 7 Map

# %%
Map = geemap.Map(center=(32, -82.8297), zoom=8)

#Add permanent water layer to map, clip map to region of interest
Map.addLayer(permanent_water_ls8.selfMask().clip(region),{"min":0, "max":1,"palette": cm.palettes.Blues}, 'Permanent Water map') 

#Add flood water layer to map, clip map to region of interest
Map.addLayer(floods_ls8.selfMask().clip(region),{"min":0, "max":1,"palette":cm.palettes.Reds}, 'Landsat 8 Flood map')

#Add flood water layer to map, clip map to region of interest
Map.addLayer(floods_ls7.selfMask().clip(region),{"min":0, "max":1,"palette":cm.palettes.Reds}, 'Landsat 7 Flood map')

#Add county layers
Map.addLayer(region)

Map.addLayerControl()
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_18cf5968c7c02d8bc3920255c3b71d71 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_18cf5968c7c02d8bc3920255c3b71d71&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_18cf5968c7c02d8bc3920255c3b71d71 = L.map(
#                 &quot;map_18cf5968c7c02d8bc3920255c3b71d71&quot;,
#                 {
#                     center: [32.0, -82.8297],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: true,
#                     pluginFullscreen: true,
#                     pluginDraw: false,
#                     DrawExport: true,
#                     pluginMinimap: false,
#                     pluginLayercontrol: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_68f9140c786bbf3f16cf6f48bdb45a84 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_18cf5968c7c02d8bc3920255c3b71d71);
#
#
#             var tile_layer_6cf968d28c3925ec9568f04c9055c8b7 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_18cf5968c7c02d8bc3920255c3b71d71);
#
#
#                 var lat_lng_popup_6c0e64909393cd8f8284746da24f2ece = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_6c0e64909393cd8f8284746da24f2ece
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_18cf5968c7c02d8bc3920255c3b71d71);
#                     }
#                 map_18cf5968c7c02d8bc3920255c3b71d71.on(&#x27;click&#x27;, latLngPop);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_18cf5968c7c02d8bc3920255c3b71d71);
#
#
#             map_18cf5968c7c02d8bc3920255c3b71d71.fitBounds(
#                 [[32, -82.8297], [32, -82.8297]],
#                 {&quot;maxZoom&quot;: 8}
#             );
#
#
#             var tile_layer_7a11e47f621ae0e514f0696b92219b67 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/dae8af866a28a6744be4e58cb331cc69-81d99fbb553169f4c1a9b0410c9f9279/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1.0, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_18cf5968c7c02d8bc3920255c3b71d71);
#
#
#             var tile_layer_5280b62cf649834b0583586f7d1e8d2a = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/d93322843e1e30f8e6a9a49318ffe8b9-c72d1ea54f9be6d664f8998447dd788a/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1.0, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_18cf5968c7c02d8bc3920255c3b71d71);
#
#
#             var tile_layer_5797493e56152111f7e325e953a5eaae = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/8ccf6db8749369304807a1e97de2f046-6a1245e7000418a36da71dcca89f12c2/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1.0, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_18cf5968c7c02d8bc3920255c3b71d71);
#
#
#             var tile_layer_54408f22c2c

# %%
# export image using HYDRAFloods export image function. below is function with its parameters
# if the export times out or is taking too long, try exporting at a larger scale (ex 90m)
# can change export_type = 'toAsset'

# hf.export_image(floods_ls7, region, description = "clipped_combined_ls7&8", scale=30, crs='EPSG:4326', pyramiding=".default:mode", export_type='toDrive')

# %%
task = ee.batch.Export.image.toDrive(image=floods_ls8,
                                     description='ls8',
                                     scale=30,
                                     region= region,
                                     crs='EPSG:4326',
                                     fileFormat='GeoTIFF')
task.start()

# %%
task.status()
# Out:
# {'state': 'READY',
#  'description': 'ls8',
#  'creation_timestamp_ms': 1667323986338,
#  'update_timestamp_ms': 1667323986338,
#  'start_timestamp_ms': 0,
#  'task_type': 'EXPORT_IMAGE',
#  'id': '2VT7XB6SOWBWG2D45PB6EG54',
#  'name': 'projects/earthengine-legacy/operations/2VT7XB6SOWBWG2D45PB6EG54'}

# %% [markdown]
# ## Sentinel 2
